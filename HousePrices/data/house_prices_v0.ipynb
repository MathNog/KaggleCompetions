# %%
import pandas as pd
import numpy as np
import os

from datetime import datetime

from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder
import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %%
def RMSE(y, y_hat):
    return np.sqrt(mean_squared_error(y, y_hat))

def MAPE(y, y_hat):
    return mean_absolute_percentage_error(y_pred=y_hat, y_true=y)

def timer(start_time=None):
    if not start_time:
        start_time = datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
" Importing data "
path = os.getcwd() + "\\"
df_train = pd.read_csv(path+"train.csv")
df_test = pd.read_csv(path+"test.csv")
df_test_id = df_test.Id

# %%
"""
First things first, lets check for missing values in the dataset
Then, I will drop every collumn with more than 10% of missing values and fill the remaining ones with the column median
"""
cols_to_keep = []
for col in df_train.columns:
    N       = len(df_train[col])
    num_na  = df_train[col].isna().sum()
    perc_na = 100*num_na/N
    print("%s -> %.2f"%(col, perc_na))
    if perc_na <= 10:
        cols_to_keep.append(col)

df_train = df_train.loc[:,cols_to_keep]
df_test  = df_test.loc[:,cols_to_keep[0:-1]]

print("Shape dt_train = (%d, %d)"%(df_train.shape[0],df_train.shape[1]))
print("Shape dt_test = (%d, %d)"%(df_test.shape[0],df_test.shape[1]))
# Out:
# Id -> 0.00
# MSSubClass -> 0.00
# MSZoning -> 0.00
# LotFrontage -> 17.74
# LotArea -> 0.00
# Street -> 0.00
# Alley -> 93.77
# LotShape -> 0.00
# LandContour -> 0.00
# Utilities -> 0.00
# LotConfig -> 0.00
# LandSlope -> 0.00
# Neighborhood -> 0.00
# Condition1 -> 0.00
# Condition2 -> 0.00
# BldgType -> 0.00
# HouseStyle -> 0.00
# OverallQual -> 0.00
# OverallCond -> 0.00
# YearBuilt -> 0.00
# YearRemodAdd -> 0.00
# RoofStyle -> 0.00
# RoofMatl -> 0.00
# Exterior1st -> 0.00
# Exterior2nd -> 0.00
# MasVnrType -> 59.73
# MasVnrArea -> 0.55
# ExterQual -> 0.00
# ExterCond -> 0.00
# Foundation -> 0.00
# BsmtQual -> 2.53
# BsmtCond -> 2.53
# BsmtExposure -> 2.60
# BsmtFinType1 -> 2.53
# BsmtFinSF1 -> 0.00
# BsmtFinType2 -> 2.60
# BsmtFinSF2 -> 0.00
# BsmtUnfSF -> 0.00
# TotalBsmtSF -> 0.00
# Heating -> 0.00
# HeatingQC -> 0.00
# CentralAir -> 0.00
# Electrical -> 0.07
# 1stFlrSF -> 0.00
# 2ndFlrSF -> 0.00
# LowQualFinSF -> 0.00
# GrLivArea -> 0.00
# BsmtFullBath -> 0.00
# BsmtHalfBath -> 0.00
# FullBath -> 0.00
# HalfBath -> 0.00
# BedroomAbvGr -> 0.00
# KitchenAbvGr -> 0.00
# KitchenQual -> 0.00
# TotRmsAbvGrd -> 0.00
# Functional -> 0.00
# Fireplaces -> 0.00
# FireplaceQu -> 47.26
# GarageType -> 5.55
# GarageYrBlt -> 5.55
# GarageFinish -> 5.55
# GarageCars -> 0.00
# GarageArea -> 0.00
# GarageQual -> 5.55
# GarageCond -> 5.55
# PavedDrive -> 0.00
# WoodDeckSF -> 0.00
# OpenPorchSF -> 0.00
# EnclosedPorch -> 0.00
# 3SsnPorch -> 0.00
# ScreenPorch -> 0.00
# PoolArea -> 0.00
# PoolQC -> 99.52
# Fence -> 80.75
# MiscFeature -> 96.30
# MiscVal -> 0.00
# MoSold -> 0.00
# YrSold -> 0.00
# SaleType -> 0.00
# SaleCondition -> 0.00
# SalePrice -> 0.00
# Shape dt_train = (1460, 74)
# Shape dt_test = (1459, 73)

# %%
" Now I will fill every missing value from a numeric column as the column's median wile also filling every string missing value as NA"

for col in df_train.columns:
    if df_train[col].isna().sum() > 0 :
        print("NA prior = ",df_train[col].isna().sum())
        if isinstance(df_train[col].iloc[0], (int, float)):
            print("%s fill with median"%col)
            train_median = np.nanmedian(df_train[col])
            df_train[col] = df_train[col].astype('float64')
            df_train[col].fillna(train_median, inplace = True)
        else:
            print("%s fill with NA as string"%col)
            df_train[col].fillna("NA", inplace = True)
        print("NA after = ",df_train[col].isna().sum())

for col in df_test.columns:
    if df_test[col].isna().sum() > 0 :
        if isinstance(df_test[col].iloc[0], (int, float)):
            print("%s fill with median"%col)
            test_median  = np.nanmedian(df_test[col])
            df_test[col] = df_test[col].astype('float64')
            df_test[col].fillna(test_median, inplace = True)
        else:
            print("%s fill with NA as string"%col)
            df_test[col].fillna("NA", inplace = True)
# Out:
# NA prior =  8
# MasVnrArea fill with median
# NA after =  0
# NA prior =  37
# BsmtQual fill with NA as string
# NA after =  0
# NA prior =  37
# BsmtCond fill with NA as string
# NA after =  0
# NA prior =  38
# BsmtExposure fill with NA as string
# NA after =  0
# NA prior =  37
# BsmtFinType1 fill with NA as string
# NA after =  0
# NA prior =  38
# BsmtFinType2 fill with NA as string
# NA after =  0
# NA prior =  1
# Electrical fill with NA as string
# NA after =  0
# NA prior =  81
# GarageType fill with NA as string
# NA after =  0
# NA prior =  81
# GarageYrBlt fill with median
# NA after =  0
# NA prior =  81
# GarageFinish fill with NA as string
# NA after =  0
# NA prior =  81
# GarageQual fill with NA as string
# NA after =  0
# NA prior =  81
# GarageCond fill with NA as string
# NA after =  0
# MSZoning fill with NA as string
# Utilities fill with NA as string
# Exterior1st fill with NA as string
# Exterior2nd fill with NA as string
# MasVnrArea fill with median
# BsmtQual fill with NA as string
# BsmtCond fill with NA as string
# BsmtExposure fill with NA as string
# BsmtFinType1 fill with NA as string
# BsmtFinSF1 fill with median
# BsmtFinType2 fill with NA as string
# BsmtFinSF2 fill with median
# BsmtUnfSF fill with median
# TotalBsmtSF fill with median
# BsmtFullBath fill with median
# BsmtHalfBath fill with median
# KitchenQual fill with NA as string
# Functional fill with NA as string
# GarageType fill with NA as string
# GarageYrBlt fill with median
# GarageFinish fill with NA as string
# GarageCars fill with median
# GarageArea fill with median
# GarageQual fill with NA as string
# GarageCond fill with NA as string
# SaleType fill with NA as string

# %%
" We have to take care of the string columns - lets do a One Hot Encoding to each of them "
for col in df_train.columns:
    if not pd.api.types.is_numeric_dtype(df_train[col][0]):
        print(col)
        encoder = OneHotEncoder()
        df_aux = pd.DataFrame(encoder.fit_transform(df_train[[col]]).toarray())
        unique_values = df_train[col].unique()
        df_aux.columns = [col+"_"+unique_values[i] for i in range(0,len(unique_values))]
        print("Len new columns = ",len(df_aux.columns))
        print("Total columns prior drop = ",df_train.shape[1])
        df_train.drop(col, axis = 1, inplace = True)
        print("Total columns after drop = ",df_train.shape[1])
        df_train = pd.concat([df_train, df_aux], axis = 1)
        print("Total columns after add = ",df_train.shape[1])

for col in df_test.columns:
    if not pd.api.types.is_numeric_dtype(df_test[col][0]):
        print(col)
        encoder = OneHotEncoder()
        df_aux = pd.DataFrame(encoder.fit_transform(df_test[[col]]).toarray())
        unique_values = df_test[col].unique()
        print(unique_values)
        df_aux.columns = [col+"_"+unique_values[i] for i in range(0,len(unique_values))]
        print("Len new columns = ",len(df_aux.columns))
        print("Total columns prior drop = ",df_test.shape[1])
        df_test.drop(col, axis = 1, inplace = True)
        print("Total columns after drop = ",df_test.shape[1])
        df_test = pd.concat([df_test, df_aux], axis = 1)
        print("Total columns after add = ",df_test.shape[1])

common_cols = list(set(df_test.columns) & set(df_train.columns))
sale_price = df_train.SalePrice

df_test = df_test.loc[:, common_cols]
df_train = df_train.loc[:, common_cols]
df_train['SalePrice'] = sale_price

print("Shape dt_train = (%d, %d)"%(df_train.shape[0],df_train.shape[1]))
print("Shape dt_test = (%d, %d)"%(df_test.shape[0],df_test.shape[1]))
# Out:
# MSZoning
# Len new columns =  5
# Total columns prior drop =  74
# Total columns after drop =  73
# Total columns after add =  78
# Street
# Len new columns =  2
# Total columns prior drop =  78
# Total columns after drop =  77
# Total columns after add =  79
# LotShape
# Len new columns =  4
# Total columns prior drop =  79
# Total columns after drop =  78
# Total columns after add =  82
# LandContour
# Len new columns =  4
# Total columns prior drop =  82
# Total columns after drop =  81
# Total columns after add =  85
# Utilities
# Len new columns =  2
# Total columns prior drop =  85
# Total columns after drop =  84
# Total columns after add =  86
# LotConfig
# Len new columns =  5
# Total columns prior drop =  86
# Total columns after drop =  85
# Total columns after add =  90
# LandSlope
# Len new columns =  3
# Total columns prior drop =  90
# Total columns after drop =  89
# Total columns after add =  92
# Neighborhood
# Len new columns =  25
# Total columns prior drop =  92
# Total columns after drop =  91
# Total columns after add =  116
# Condition1
# Len new columns =  9
# Total columns prior drop =  116
# Total columns after drop =  115
# Total columns after add =  124
# Condition2
# Len new columns =  8
# Total columns prior drop =  124
# Total columns after drop =  123
# Total columns after add =  131
# BldgType
# Len new columns =  5
# Total columns prior drop =  131
# Total columns after drop =  130
# Total columns after add =  135
# HouseStyle
# Len new columns =  8
# Total columns prior drop =  135
# Total columns after drop =  134
# Total columns after add =  142
# RoofStyle
# Len new columns =  6
# Total columns prior drop =  142
# Total columns after drop =  141
# Total columns after add =  147
# RoofMatl
# Len new columns =  8
# Total columns prior drop =  147
# Total columns after drop =  146
# Total columns after add =  154
# Exterior1st
# Len new columns =  15
# Total columns prior drop =  154
# Total columns after drop =  153
# Total columns after add =  168
# Exterior2nd
# Len new columns =  16
# Total columns prior drop =  168
# Total columns after drop =  167
# Total columns after add =  183
# ExterQual
# Len new columns =  4
# Total columns prior drop =  183
# Total columns after drop =  182
# Total columns after add =  186
# ExterCond
# Len new columns =  5
# Total columns prior drop =  186
# Total columns after drop =  185
# Total columns after add =  190
# Foundation
# Len new columns =  6
# Total columns prior drop =  190
# Total columns after drop =  189
# Total columns after add =  195
# BsmtQual
# Len new columns =  5
# Total columns prior drop =  195
# Total columns after drop =  194
# Total columns after add =  199
# BsmtCond
# Len new columns =  5
# Total columns prior drop =  199
# Total columns after drop =  198
# Total columns after add =  203
# BsmtExposure
# Len new columns =  5
# Total columns prior drop =  203
# Total columns after drop =  202
# Total columns after add =  207
# BsmtFinType1
# Len new columns =  7
# Total columns prior drop =  207
# Total columns after drop =  206
# Total columns after add =  213
# BsmtFinType2
# Len new columns =  7
# Total columns prior drop =  213
# Total columns after drop =  212
# Total columns after add =  219
# Heating
# Len new columns =  6
# Total columns prior drop =  219
# Total columns after drop =  218
# Total columns after add =  224
# HeatingQC
# Len new columns =  5
# Total columns prior drop =  224
# Total columns after drop =  223
# Total columns after add =  228
# CentralAir
# Len new columns =  2
# Total columns prior drop =  228
# Total columns after drop =  227
# Total columns after add =  229
# Electrical
# Len new columns =  6
# Total columns prior drop =  229
# Total columns after drop =  228
# Total columns after add =  234
# KitchenQual
# Len new columns =  4
# Total columns prior drop =  234
# Total columns after drop =  233
# Total columns after add =  237
# Functional
# Len new columns =  7
# Total columns prior drop =  237
# Total columns after drop =  236
# Total columns after add =  243
# GarageType
# Len new columns =  7
# Total columns prior drop =  243
# Total columns after drop =  242
# Total columns after add =  249
# GarageFinish
# Len new columns =  4
# Total columns prior drop =  249
# Total columns after drop =  248
# Total columns after add =  252
# GarageQual
# Len new columns =  6
# Total columns prior drop =  252
# Total columns after drop =  251
# Total columns after add =  257
# GarageCond
# Len new columns =  6
# Total columns prior drop =  257
# Total columns after drop =  256
# Total columns after add =  262
# PavedDrive
# Len new columns =  3
# Total columns prior drop =  262
# Total columns after drop =  261
# Total columns after add =  264
# SaleType
# Len new columns =  9
# Total columns prior drop =  264
# Total columns after drop =  263
# Total columns after add =  272
# SaleCondition
# Len new columns =  6
# Total columns prior drop =  272
# Total columns after drop =  271
# Total columns after add =  277
# MSZoning
# ['RH' 'RL' 'RM' 'FV' 'C (all)' 'NA']
# Len new columns =  6
# Total columns prior drop =  73
# Total columns after drop =  72
# Total columns after add =  78
# Street
# ['Pave' 'Grvl']
# Len new columns =  2
# Total columns prior drop =  78
# Total columns after drop =  77
# Total columns after add =  79
# LotShape
# ['Reg' 'IR1' 'IR2' 'IR3']
# Len new columns =  4
# Total columns prior drop =  79
# Total columns after drop =  78
# Total columns after add =  82
# LandContour
# ['Lvl' 'HLS' 'Bnk' 'Low']
# Len new columns =  4
# Total columns prior drop =  82
# Total columns after drop =  81
# Total columns after add =  85
# Utilities
# ['AllPub' 'NA']
# Len new columns =  2
# Total columns prior drop =  85
# Total columns after drop =  84
# Total columns after add =  86
# LotConfig
# ['Inside' 'Corner' 'FR2' 'CulDSac' 'FR3']
# Len new columns =  5
# Total columns prior drop =  86
# Total columns after drop =  85
# Total columns after add =  90
# LandSlope
# ['Gtl' 'Mod' 'Sev']
# Len new columns =  3
# Total columns prior drop =  90
# Total columns after drop =  89
# Total columns after add =  92
# Neighborhood
# ['NAmes' 'Gilbert' 'StoneBr' 'BrDale' 'NPkVill' 'NridgHt' 'Blmngtn'
#  'NoRidge' 'Somerst' 'SawyerW' 'Sawyer' 'NWAmes' 'OldTown' 'BrkSide'
#  'ClearCr' 'SWISU' 'Edwards' 'CollgCr' 'Crawfor' 'Blueste' 'IDOTRR'
#  'Mitchel' 'Timber' 'MeadowV' 'Veenker']
# Len new columns =  25
# Total columns prior drop =  92
# Total columns after drop =  91
# Total columns after add =  116
# Condition1
# ['Feedr' 'Norm' 'PosN' 'RRNe' 'Artery' 'RRNn' 'PosA' 'RRAn' 'RRAe']
# Len new columns =  9
# Total columns prior drop =  116
# Total columns after drop =  115
# Total columns after add =  124
# Condition2
# ['Norm' 'Feedr' 'PosA' 'PosN' 'Artery']
# Len new columns =  5
# Total columns prior drop =  124
# Total columns after drop =  123
# Total columns after add =  128
# BldgType
# ['1Fam' 'TwnhsE' 'Twnhs' 'Duplex' '2fmCon']
# Len new columns =  5
# Total columns prior drop =  128
# Total columns after drop =  127
# Total columns after add =  132
# HouseStyle
# ['1Story' '2Story' 'SLvl' '1.5Fin' 'SFoyer' '2.5Unf' '1.5Unf']
# Len new columns =  7
# Total columns prior drop =  132
# Total columns after drop =  131
# Total columns after add =  138
# RoofStyle
# ['Gable' 'Hip' 'Gambrel' 'Flat' 'Mansard' 'Shed']
# Len new columns =  6
# Total columns prior drop =  138
# Total columns after drop =  137
# Total columns after add =  143
# RoofMatl
# ['CompShg' 'Tar&Grv' 'WdShake' 'WdShngl']
# Len new columns =  4
# Total columns prior drop =  143
# Total columns after drop =  142
# Total columns after add =  146
# Exterior1st
# ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'CemntBd' 'WdShing'
#  'BrkFace' 'AsbShng' 'BrkComm' 'Stucco' 'AsphShn' 'NA' 'CBlock']
# Len new columns =  14
# Total columns prior drop =  146
# Total columns after drop =  145
# Total columns after add =  159
# Exterior2nd
# ['VinylSd' 'Wd Sdng' 'HdBoard' 'Plywood' 'MetalSd' 'Brk Cmn' 'CmentBd'
#  'ImStucc' 'Wd Shng' 'AsbShng' 'Stucco' 'CBlock' 'BrkFace' 'AsphShn' 'NA'
#  'Stone']
# Len new columns =  16
# Total columns prior drop =  159
# Total columns after drop =  158
# Total columns after add =  174
# ExterQual
# ['TA' 'Gd' 'Ex' 'Fa']
# Len new columns =  4
# Total columns prior drop =  174
# Total columns after drop =  173
# Total columns after add =  177
# ExterCond
# ['TA' 'Gd' 'Fa' 'Po' 'Ex']
# Len new columns =  5
# Total columns prior drop =  177
# Total columns after drop =  176
# Total columns after add =  181
# Foundation
# ['CBlock' 'PConc' 'BrkTil' 'Stone' 'Slab' 'Wood']
# Len new columns =  6
# Total columns prior drop =  181
# Total columns after drop =  180
# Total columns after add =  186
# BsmtQual
# ['TA' 'Gd' 'Ex' 'Fa' 'NA']
# Len new columns =  5
# Total columns prior drop =  186
# Total columns after drop =  185
# Total columns after add =  190
# BsmtCond
# ['TA' 'Po' 'Fa' 'Gd' 'NA']
# Len new columns =  5
# Total columns prior drop =  190
# Total columns after drop =  189
# Total columns after add =  194
# BsmtExposure
# ['No' 'Gd' 'Mn' 'Av' 'NA']
# Len new columns =  5
# Total columns prior drop =  194
# Total columns after drop =  193
# Total columns after add =  198
# BsmtFinType1
# ['Rec' 'ALQ' 'GLQ' 'Unf' 'BLQ' 'LwQ' 'NA']
# Len new columns =  7
# Total columns prior drop =  198
# Total columns after drop =  197
# Total columns after add =  204
# BsmtFinType2
# ['LwQ' 'Unf' 'Rec' 'BLQ' 'GLQ' 'ALQ' 'NA']
# Len new columns =  7
# Total columns prior drop =  204
# Total columns after drop =  203
# Total columns after add =  210
# Heating
# ['GasA' 'GasW' 'Grav' 'Wall']
# Len new columns =  4
# Total columns prior drop =  210
# Total columns after drop =  209
# Total columns after add =  213
# HeatingQC
# ['TA' 'Gd' 'Ex' 'Fa' 'Po']
# Len new columns =  5
# Total columns prior drop =  213
# Total columns after drop =  212
# Total columns after add =  217
# CentralAir
# ['Y' 'N']
# Len new columns =  2
# Total columns prior drop =  217
# Total columns after drop =  216
# Total columns after add =  218
# Electrical
# ['SBrkr' 'FuseA' 'FuseF' 'FuseP']
# Len new columns =  4
# Total columns prior drop =  218
# Total columns after drop =  217
# Total columns after add =  221
# KitchenQual
# ['TA' 'Gd' 'Ex' 'Fa' 'NA']
# Len new columns =  5
# Total columns prior drop =  221
# Total columns after drop =  220
# Total columns after add =  225
# Functional
# ['Typ' 'Min2' 'Min1' 'Mod' 'Maj1' 'Sev' 'Maj2' 'NA']
# Len new columns =  8
# Total columns prior drop =  225
# Total columns after drop =  224
# Total columns after add =  232
# GarageType
# ['Attchd' 'Detchd' 'BuiltIn' 'NA' 'Basment' '2Types' 'CarPort']
# Len new columns =  7
# Total columns prior drop =  232
# Total columns after drop =  231
# Total columns after add =  238
# GarageFinish
# ['Unf' 'Fin' 'RFn' 'NA']
# Len new columns =  4
# Total columns prior drop =  238
# Total columns after drop =  237
# Total columns after add =  241
# GarageQual
# ['TA' 'NA' 'Fa' 'Gd' 'Po']
# Len new columns =  5
# Total columns prior drop =  241
# Total columns after drop =  240
# Total columns after add =  245
# GarageCond
# ['TA' 'NA' 'Fa' 'Gd' 'Po' 'Ex']
# Len new columns =  6
# Total columns prior drop =  245
# Total columns after drop =  244
# Total columns after add =  250
# PavedDrive
# ['Y' 'N' 'P']
# Len new columns =  3
# Total columns prior drop =  250
# Total columns after drop =  249
# Total columns after add =  252
# SaleType
# ['WD' 'COD' 'New' 'ConLD' 'Oth' 'Con' 'ConLw' 'ConLI' 'CWD' 'NA']
# Len new columns =  10
# Total columns prior drop =  252
# Total columns after drop =  251
# Total columns after add =  261
# SaleCondition
# ['Normal' 'Partial' 'Abnorml' 'Family' 'Alloca' 'AdjLand']
# Len new columns =  6
# Total columns prior drop =  261
# Total columns after drop =  260
# Total columns after add =  266
# Shape dt_train = (1460, 260)
# Shape dt_test = (1459, 259)

# %%
" Now that our dataset is clean, lets divide the train dataset into a fit and validation datasets"

X = df_train.drop(columns="SalePrice")
y = df_train.SalePrice

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
n_estimators  = [1500, 2500]
max_depth     = [3, 5]
max_leaves    = [3, 5]
learning_rate = [0.01, 0.001]
booster       = ['gbtree', 'gblinear'] # gbtree, gblinear or dart
random_state  = [0]
eval_metric   = mean_squared_error  
early_stopping_rounds = [3, 5]

params = {  'n_estimators'  : n_estimators,
            'max_depth'     : max_depth,
            'max_leaves'    : max_leaves,
            'learning_rate' : learning_rate,
            'booster'       : booster,
            'random_state'  : random_state,
            # 'early_stopping_rounds': early_stopping_rounds
}

reg = xgb.XGBRegressor(silent = True)

# %%
skf = StratifiedKFold(n_splits=5, shuffle = True, random_state = 0)

random_search = GridSearchCV(reg, param_grid = params, scoring = 'neg_root_mean_squared_error', cv = skf.split(X_train,y_train))

# %%
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(X_train, y_train)
timer(start_time) # timing ends here for "start_time" variable
# Out:
#  Time taken: 0 hours 13 minutes and 24.58 seconds.

# %%
print(random_search.best_params_)

random_state = random_search.best_params_["random_state"]
n_estimators = random_search.best_params_["n_estimators"]
max_leaves = random_search.best_params_["max_leaves"]
max_depth = random_search.best_params_["max_depth"]
learning_rate = random_search.best_params_["learning_rate"]
booster = random_search.best_params_["booster"]

reg = xgb.XGBRegressor(silent = True, random_state = random_state,
                        n_estimators = n_estimators, max_leaves = max_leaves,
                        max_depth = max_depth, learning_rate = learning_rate,
                        booster = booster)
# Out:
# {'booster': 'gbtree', 'learning_rate': 0.01, 'max_depth': 5, 'max_leaves': 5, 'n_estimators': 2500, 'random_state': 0}

# %%
start_time = timer(None)
reg.fit(X_train,y_train);
timer(start_time)
# Out:
#  Time taken: 0 hours 0 minutes and 7.4 seconds.

# %%
y_hat_train = reg.predict(X_train)
y_hat_val   = reg.predict(X_val)

# %%
print("MAPE train = ",MAPE(y_train, y_hat_train))
print("MAPE val = ",MAPE(y_val, y_hat_val))

print("RMSE train = ",RMSE(y_train, y_hat_train))
print("RMSE val = ",RMSE(y_val, y_hat_val))
# Out:
# MAPE train =  0.0554371102030655
# MAPE val =  0.09624251648633741
# RMSE train =  13016.30459074641
# RMSE val =  30648.841101424172

# %%
reg = xgb.XGBRegressor(silent = True, random_state = random_state,
                        n_estimators = n_estimators, max_leaves = max_leaves,
                        max_depth = max_depth, learning_rate = learning_rate,
                        booster = booster)

start_time = timer(None)
reg.fit(X,y);
timer(start_time)
# Out:
#  Time taken: 0 hours 0 minutes and 4.68 seconds.

# %%
X_test = df_test

y_hat      = reg.predict(X)
y_hat_test = reg.predict(X_test)

print("MAPE = ",MAPE(y, y_hat))
print("RMSE = ",RMSE(y, y_hat))

prediction = pd.DataFrame({"Id":df_test_id, "SalePrice":y_hat_test})
prediction.to_csv("test_prediction_xgboost_v0.csv", index=False)
# Out:
# MAPE =  0.06443982043560775
# RMSE =  14866.262671218194
